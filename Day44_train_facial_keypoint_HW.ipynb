# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96；data.shape[0]打印出來為img的張數
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
#verbose: 詳細訊息模式，0 或者 1; save_best_only=True，最佳模型不會被覆蓋; 如果是最好的model就存到best_weights.h5這個檔案
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), #reshape(-1,)表示列數固定
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=15, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')  #把訓練好的model存檔
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/15
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0056 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00204, saving model to best_weights.h5
# Epoch 2/15
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0015 - val_loss: 0.0022
#
# Epoch 00002: val_loss did not improve from 0.00204
# Epoch 3/15
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00204 to 0.00188, saving model to best_weights.h5
# Epoch 4/15
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00188 to 0.00187, saving model to best_weights.h5
# Epoch 5/15
# 1712/1712 [==============================] - 9s 5ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00187 to 0.00182, saving model to best_weights.h5
# Epoch 6/15
# 1712/1712 [==============================] - 9s 5ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00182 to 0.00177, saving model to best_weights.h5
# Epoch 7/15
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.1430e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00177 to 0.00163, saving model to best_weights.h5
# Epoch 8/15
# 1712/1712 [==============================] - 9s 5ms/step - loss: 7.7367e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00163 to 0.00144, saving model to best_weights.h5
# Epoch 9/15
# 1712/1712 [==============================] - 9s 5ms/step - loss: 6.7592e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00144 to 0.00134, saving model to best_weights.h5
# Epoch 10/15
# 1712/1712 [==============================] - 9s 5ms/step - loss: 6.0083e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00134 to 0.00124, saving model to best_weights.h5
# Epoch 11/15
# 1712/1712 [==============================] - 9s 5ms/step - loss: 5.4335e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00124 to 0.00113, saving model to best_weights.h5
# Epoch 12/15
# 1712/1712 [==============================] - 9s 5ms/step - loss: 4.9389e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00113 to 0.00110, saving model to best_weights.h5
# Epoch 13/15
# 1712/1712 [==============================] - 9s 5ms/step - loss: 4.6417e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00110 to 0.00105, saving model to best_weights.h5
# Epoch 14/15
# 1712/1712 [==============================] - 9s 5ms/step - loss: 4.3385e-04 - val_loss: 9.4634e-04
#
# Epoch 00014: val_loss improved from 0.00105 to 0.00095, saving model to best_weights.h5
# Epoch 15/15
# 1712/1712 [==============================] - 10s 6ms/step - loss: 4.1521e-04 - val_loss: 9.6943e-04
#
# Epoch 00015: val_loss did not improve from 0.00095

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')
#print(imgs_test,imgs_test.shape) #imgs_test.shape為(1783, 96, 96)

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')   #要記得先前的座標已經被normalize了

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))
print(points_test.shape)  #輸入人臉圖片，預測座標點，這邊的points_test就是預測出來的座標點
print(points_test[0])

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))   
    # plot_keypoints(圖片, 座標) 其實還可以很多參數; np.squeeze用來刪除維度
print(np.squeeze(points_test[0]))   #但是打印出來感覺一樣???????
# Out:
# (1783, 30)
# [ 0.20451342 -0.11514255 -0.1983611  -0.1148617   0.13354783 -0.10724764
#   0.26517665 -0.10158401 -0.12782653 -0.10978737 -0.2596785  -0.10181235
#   0.10368232 -0.21926852  0.33069712 -0.19130462 -0.0982709  -0.21738277
#  -0.327531   -0.19348724  0.00286208  0.03920716  0.15663777  0.29092202
#  -0.15985897  0.28410488 -0.00432528  0.20838118 -0.00216514  0.3690158 ]
# [ 0.20451342 -0.11514255 -0.1983611  -0.1148617   0.13354783 -0.10724764
#   0.26517665 -0.10158401 -0.12782653 -0.10978737 -0.2596785  -0.10181235
#   0.10368232 -0.21926852  0.33069712 -0.19130462 -0.0982709  -0.21738277
#  -0.327531   -0.19348724  0.00286208  0.03920716  0.15663777  0.29092202
#  -0.15985897  0.28410488 -0.00432528  0.20838118 -0.00216514  0.3690158 ]

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code

# 實現圖片以及關鍵點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape   #其實這個img的shape就是96*96*1。1不算，rows/cols都是96
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            #print(new_img)
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[1], points_train[1])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[1], points_train[1])    # 原來的圖片   ax = fig.add_subplot(349) =>把圖片放在3*4排列的第9塊
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points)    # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation, 原本有2140張
for i in range(imgs_train.shape[0]): 
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=15, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/15
# 3424/3424 [==============================] - 19s 6ms/step - loss: 0.0055 - val_loss: 0.0018
#
# Epoch 00001: val_loss improved from inf to 0.00185, saving model to best_weights_augment.h5
# Epoch 2/15
# 3424/3424 [==============================] - 20s 6ms/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00002: val_loss did not improve from 0.00185
# Epoch 3/15
# 3424/3424 [==============================] - 20s 6ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00003: val_loss did not improve from 0.00185
# Epoch 4/15
# 3424/3424 [==============================] - 20s 6ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00185 to 0.00181, saving model to best_weights_augment.h5
# Epoch 5/15
# 3424/3424 [==============================] - 18s 5ms/step - loss: 8.7618e-04 - val_loss: 0.0017
#
# Epoch 00005: val_loss improved from 0.00181 to 0.00166, saving model to best_weights_augment.h5
# Epoch 6/15
# 3424/3424 [==============================] - 22s 6ms/step - loss: 7.1546e-04 - val_loss: 0.0014
#
# Epoch 00006: val_loss improved from 0.00166 to 0.00136, saving model to best_weights_augment.h5
# Epoch 7/15
# 3424/3424 [==============================] - 22s 6ms/step - loss: 6.0528e-04 - val_loss: 0.0012
#
# Epoch 00007: val_loss improved from 0.00136 to 0.00122, saving model to best_weights_augment.h5
# Epoch 8/15
# 3424/3424 [==============================] - 22s 6ms/step - loss: 5.4077e-04 - val_loss: 0.0010
#
# Epoch 00008: val_loss improved from 0.00122 to 0.00104, saving model to best_weights_augment.h5
# Epoch 9/15
# 3424/3424 [==============================] - 22s 6ms/step - loss: 4.8601e-04 - val_loss: 9.8747e-04
#
# Epoch 00009: val_loss improved from 0.00104 to 0.00099, saving model to best_weights_augment.h5
# Epoch 10/15
# 3424/3424 [==============================] - 22s 6ms/step - loss: 4.3827e-04 - val_loss: 9.0737e-04
#
# Epoch 00010: val_loss improved from 0.00099 to 0.00091, saving model to best_weights_augment.h5
# Epoch 11/15
# 3424/3424 [==============================] - 22s 6ms/step - loss: 4.0827e-04 - val_loss: 8.5732e-04
#
# Epoch 00011: val_loss improved from 0.00091 to 0.00086, saving model to best_weights_augment.h5
# Epoch 12/15
# 3424/3424 [==============================] - 21s 6ms/step - loss: 3.8291e-04 - val_loss: 8.3152e-04
#
# Epoch 00012: val_loss improved from 0.00086 to 0.00083, saving model to best_weights_augment.h5
# Epoch 13/15
# 3424/3424 [==============================] - 22s 6ms/step - loss: 3.6017e-04 - val_loss: 8.5742e-04
#
# Epoch 00013: val_loss did not improve from 0.00083
# Epoch 14/15
# 3424/3424 [==============================] - 22s 6ms/step - loss: 3.3917e-04 - val_loss: 7.9000e-04
#
# Epoch 00014: val_loss improved from 0.00083 to 0.00079, saving model to best_weights_augment.h5
# Epoch 15/15
# 3424/3424 [==============================] - 17s 5ms/step - loss: 3.2580e-04 - val_loss: 7.7522e-04
#
# Epoch 00015: val_loss improved from 0.00079 to 0.00078, saving model to best_weights_augment.h5

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
